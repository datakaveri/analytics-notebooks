# %% [markdown]
# ## Import Packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
from tensorflow.keras import losses
from tensorflow.keras import metrics
from tensorflow.keras import initializers
from keras.callbacks import EarlyStopping
import tensorflow as tf
from keras import Input
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error as mae
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import pandas as pd
import geopandas as gp

# %% [markdown]
# ## Import Required Data

# %%
#time_series_data = genfromtxt('time_series_data_pm2p5.csv', delimiter=',', skip_header = 1)
time_series_data = genfromtxt('GRIN_Imputed_Pune_Data.csv', delimiter=',', skip_header = 1) # Load GRIN Imputed Data
Aqm_Pune = pd.read_csv('pune-aqm.csv')
Sensor_Location = pd.read_csv('pune_sensor.csv')
map_ms=gp.read_file('maharashtra_administrative/maharashtra_administrative.shp',encoding="utf-8")
map_pune = map_ms[map_ms['NAME'] == 'Pune']

# %% [markdown]
# ### Data Selection

# %%
time_series_data = time_series_data[2:,1:].T               # Discard Unwanted rows and Columns from the Data
time_series_data
# Out:
# array([[ 4.25    ,  4.25    ,  4.25    , ..., 13.      , 14.      ,
#         14.5     ],
#        [22.716587, 22.716587, 22.716587, ...,  9.408189,  9.408189,
#          9.408189],
#        [ 6.727941,  6.727941,  6.727941, ...,  3.      ,  2.      ,
#          3.      ],
#        ...,
#        [18.684256, 18.684256, 18.684256, ...,  4.375   ,  4.375   ,
#          0.      ],
#        [22.382853, 22.382853, 22.382853, ...,  3.      ,  4.      ,
#          3.      ],
#        [13.      , 13.      , 13.      , ...,  9.      ,  9.      ,
#          9.      ]])

# %% [markdown]
# ### Order Latitude and Longitude according to the Data

# %%
dum = Aqm_Pune.id.unique()    # Get all the sensor ID's
known_latlon = pd.DataFrame(columns = ['latitude', 'longitude'])       # Create an empty DataFrame to store 'known' latitude and longitude

for i in range(len(Sensor_Location)):           # Loop over all the sensor loations in the data
    single_sensor_location = Sensor_Location[Sensor_Location['id'] == dum[i]].reset_index(drop=True,inplace=False)   # Get information of a single sensor
    known_latlon.loc[len(known_latlon.index)] = [(single_sensor_location['latitude'].values)[0], (single_sensor_location['longitude'].values)[0]]    # Append dummy data frame to the ordered data frame 
#known_latlon

# %% [markdown]
# #### Create a grid of Latitude and Longitudes around existing sensor locations

# %%
lat_min = min(known_latlon['latitude']) # Minimum latitude value
lat_max = max(known_latlon['latitude']) # Maximum latitude value
lng_min = min(known_latlon['longitude']) # Minimum longitude value
lng_max = max(known_latlon['longitude']) # Maximum longitude value
ext = 0.01 # Value of extension to the grid
grid_length = 10
xx = np.linspace(lng_min-ext, lng_max+ext, grid_length) # Get 100 longitude values between maximum and minimum longitude values
yy = np.linspace(lat_min-ext, lat_max+ext, grid_length) # Get 100 latitude values between maximum and minimum latitudes values

unknown_set = np.meshgrid(xx, yy) # Get grid with arrays xx and yy
gridx = np.reshape(unknown_set[0], (1, grid_length*grid_length)) # Array of all longitude values in the grid
gridy = np.reshape(unknown_set[1], (1, grid_length*grid_length)) # Array of all latitude values in the grid

gridyx = np.concatenate((gridy.T, gridx.T), axis=1) # Concatenate latitude and longitude arrays

unknown_latlon = pd.DataFrame(columns = ['latitude', 'longitude']) # Define an empty DataFrame for unknown latitude and longitude values
unknown_latlon[['latitude', 'longitude']] = gridyx # Assign Concatenated latitude and longitude array to unknown latitude longitude DataFrame

latlon = pd.concat([known_latlon, unknown_latlon], ignore_index = True) # Concatenate both known and Unknown lat lon DataFrame with new index
#latlon

# %% [markdown]
# ### Initialize variables to get Date-Time object for Sensor Measurements for every 15 min interval

# %%
from datetime import datetime, timedelta, timezone
start_date = '2020-10-16 05:30:00'     # Starting date-time for data
#date_format_str = '%Y-%m-%d %H:%M:%S%z'
date_format_str = '%Y-%m-%d %H:%M:%S'  # Date-time format
end_date = '2022-07-21 05:30:00'       # Ending date-time for data
d0 = datetime.strptime(start_date, date_format_str) # Converting starting date-time string to datetime Object
d1 = datetime.strptime(end_date, date_format_str)   # Converting ending date-time string to datetime Object
diff = d1-d0      # Get difference between stating date-time object to ending date-time object
sampling_frequency = 0.25       # Sampling frequency (0.25 = 15min, 0.5 = 30min, 1 = 1hr)
end_slot = start_date           # Initiate ending time slot as the starting time
start_slot = datetime.strptime(start_date, date_format_str) # Initiate starting time slot as the starting time
                                                            # Initially start and end slots are the same (before iteration)

# %% [markdown]
# ### Get Date-Time object for Sensor Measurements for every 15 min interval

# %%
DateTime = start_slot  # Variable to store date-time object data, Initiate DateTime with starting date-time object and store 
for j in range(int(diff.days*24*(1/sampling_frequency))):      # Loop to get date-time objects for sensor data
    end_slot = start_slot+timedelta(hours = sampling_frequency) # Change end_slot for the loop by adding 15 mins to start_slot
    start_slot = end_slot    # Change start_slot for the next loop by assiging end_slot to start_slot
    DateTime = np.append(DateTime, start_slot)  # Append new start_slot (next date-time object) to DateTime variable

# %% [markdown]
# ### Data Selection and Data Scaling

# %%
actual_data = time_series_data#[:-1,1:1001]          # Select the data range [0,T] for reference
spatio_temporal_observations_data = time_series_data#[:-1,1:1001]   # Select the data range [0,T] for manipulation
data_scaler = StandardScaler()           # Define StandardScaler instantiation for data scaling
data_scaler.fit(spatio_temporal_observations_data)    # Fit Spatio-Temporal data using fit() method of StandardScaler
spatio_temporal_observations = data_scaler.transform(spatio_temporal_observations_data)  # Transform the Spatio-Temporal data using transform() method of StandardScaler

# %% [markdown]
# ### Principle Component Analysis

# %%
K = min(spatio_temporal_observations.shape[1], spatio_temporal_observations.shape[0]-1)   # Number of Components
pca = PCA(n_components=K)       # PCA with K components
pca.fit(spatio_temporal_observations)      # Fit PCA to Spatio-Temporal data
# Out:
# PCA(n_components=49)

# %% [markdown]
# ### Explained Variance from PCA analysis

# %%
exp_var = 0.95
explained_variance = pca.explained_variance_ratio_.cumsum()
explained_variance[explained_variance >= exp_var]
xmin = np.where(explained_variance >= exp_var)[0]

# %% [markdown]
# ### Plot Explained variance

# %%
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.vlines(x=xmin[0], ymin=explained_variance[0], ymax=exp_var, colors='green', ls=':', lw=2, label='vline_single - partial height')
plt.hlines(y=exp_var, xmin=0, xmax=xmin[0], color='green', ls=':', lw=2)
plt.title('Cumulative percentage of explained Variance')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance')
plt.show()

# %% [markdown]
# ### Computer Spatial Coefficients and Process them through standard scaler

# %%
K_ = xmin[0]
#K_ = 48
alpha_k_ = np.dot(pca.components_[:K_], spatio_temporal_observations.T)  # Spatial Coefficients = dot product of first K PCA components and Spatiotemporal Observations
coff_scaler = StandardScaler()                # Apply Standard Scaler to the Coefficients
coff_scaler.fit(alpha_k_)                     # Fit spatial coefficients to standard scaler
alpha_k = coff_scaler.transform(alpha_k_)     # Transform Spatial Coefficients through standard scaler
alpha_k.shape
# Out:
# (29, 50)

# %% [markdown]
# ### Split Data into testing and training data with indices in the original data

# %%
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(known_latlon.to_numpy(), alpha_k.T, np.arange(spatio_temporal_observations.shape[0]), test_size=0.2, random_state=0)

# %%
y_train
# Out:
# array([[-1.55309503, -2.54585542,  0.19908085, ...,  1.05151638,
#          0.84056953, -0.77311242],
#        [-4.61318189, -0.63061722,  1.02567928, ..., -0.22448778,
#         -0.1449495 ,  0.24071878],
#        [ 0.69501366,  4.44163803, -0.12954239, ...,  0.32278099,
#          0.01259071, -0.2419678 ],
#        ...,
#        [ 2.9880594 ,  0.38213881, -0.14742331, ..., -0.20862915,
#         -0.52938324, -0.11442336],
#        [ 3.70678611, -1.37720498, -0.15006614, ..., -0.01116975,
#         -0.13099383,  0.0322669 ],
#        [ 4.08922556, -0.35925605, -1.00205322, ..., -0.1835741 ,
#         -0.29935239, -0.33420926]])

# %% [markdown]
# ### Visualized coefficients

# %%
y_ini_prediction = np.dot(coff_scaler.inverse_transform(alpha_k).T, pca.components_[:K_])   # Represent data using spatial coefficients and orthogonal basis
y_ini_pred_trans = data_scaler.inverse_transform(y_ini_prediction)     # Tranform the represented data using data scaler
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(DateTime[:-1], y_ini_pred_trans[indices_test[0]], label = 'Transformed Data')     # Plot transformed data
ax.plot(DateTime[:-1], actual_data[indices_test[0]], label = 'Actual Data')          # Plot Actual Data
ax.set_ylabel('pm2.5',fontsize=20)
ax.set_xlabel('Date Time',fontsize=20)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.legend(loc='best', fontsize=16)
plt.tight_layout()
#plt.savefig('fig/ignnk_pm2p5.pdf')
plt.show()

# %%
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(DateTime[:-1], y_ini_prediction[indices_test[0]])

# %% [markdown]
# ### Model Training
# Perform model training on Spatial Coefficients\
# A sequential model with one input, one output and 6 Dense hidden layers\
# Initializer                --> HeNormal()\
# Loss Function              --> Mean Squared Error\
# Activation Function        --> relu\
# Normalization              --> Batch Normalization\
# Number of Hidden Layers    --> 6\
# Optimizer                  --> Nadam\
#                                Learning Rate - 0.0001\
#                                Metrics - Accuracy

# %%
initializer = initializers.HeNormal()    # Initializer
es = EarlyStopping(monitor='loss', mode='min', verbose=0) # Early Stopping criterion
loss_fn = losses.MeanSquaredError()      # Loss function
act_fn = 'relu'                          # Activation function

# Sequential Model with one input, one output and 6 Dense hidden layers
model = Sequential() # Model
#model.add(Dense(100, input_shape=(1,), activation="sigmoid"))
model.add(Input(shape=(2,), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model.add(BatchNormalization())
model.add(Dense(512, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer-1')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(256, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer-2')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(128, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer-3')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(64, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer_4')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(32, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer-5')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(16, activation= act_fn, kernel_initializer=initializer, name='Hidden-Layer-6')) # Hidden Layer, softplus(x) = log(exp(x) + 1)
model.add(BatchNormalization())
model.add(Dense(K_, activation= act_fn, name='Output-Layer')) # Output Layer, sigmoid(x) = 1 / (1 + exp(-x))

# Compile model 
model.compile(#optimizer = SGD(learning_rate=0.01, momentum=0.9),
              optimizer = Nadam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name="Nadam"),
              #optimizer='Nadam', # default='rmsprop', an algorithm to be used in backpropagation
              loss=loss_fn, # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              #metrics=tf.keras.metrics.Metri,#, 'Precision', 'Recall'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              metrics=['Accuracy']#, 'Precision', 'Recall'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              #loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              #weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              #run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              #steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
             )

# Fit training data
model.fit(X_train, # input data
          y_train, # target data
          batch_size=4, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
          epochs=100, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
          #verbose='auto', # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
          #callbacks=[es], # default=None, list of callbacks to apply during training. See tf.keras.callbacks
          #validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
          validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
          #shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
          #class_weight={0 : 0.3, 1 : 0.7}, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
          #sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
          #initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
          #steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
          #validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
          #validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
          #validation_freq=3, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
          #max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
          #workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
          #use_multiprocessing=False, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
         )
# Out:
# 2022-09-26 11:40:16.178474: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 10/10 [==============================] - 2s 20ms/step - loss: 1.3634 - Accuracy: 0.0250 - val_loss: 545.8572 - val_Accuracy: 0.0000e+00
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2938 - Accuracy: 0.0000e+00 - val_loss: 469.6295 - val_Accuracy: 0.0000e+00
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2901 - Accuracy: 0.0750 - val_loss: 424.3683 - val_Accuracy: 0.0000e+00
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3089 - Accuracy: 0.0000e+00 - val_loss: 424.2889 - val_Accuracy: 0.0000e+00
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2861 - Accuracy: 0.0250 - val_loss: 476.1364 - val_Accuracy: 0.0000e+00
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3490 - Accuracy: 0.0000e+00 - val_loss: 419.8381 - val_Accuracy: 0.0000e+00
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2977 - Accuracy: 0.0250 - val_loss: 470.8348 - val_Accuracy: 0.0000e+00
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3265 - Accuracy: 0.0500 - val_loss: 528.8665 - val_Accuracy: 0.0000e+00
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3405 - Accuracy: 0.0000e+00 - val_loss: 505.5805 - val_Accuracy: 0.0000e+00
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2928 - Accuracy: 0.0500 - val_loss: 512.4092 - val_Accuracy: 0.0000e+00
# Epoch 11/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3229 - Accuracy: 0.0500 - val_loss: 334.7177 - val_Accuracy: 0.0000e+00
# Epoch 12/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3027 - Accuracy: 0.0500 - val_loss: 248.8711 - val_Accuracy: 0.0000e+00
# Epoch 13/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2677 - Accuracy: 0.0250 - val_loss: 169.3637 - val_Accuracy: 0.0000e+00
# Epoch 14/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2596 - Accuracy: 0.1500 - val_loss: 149.9766 - val_Accuracy: 0.0000e+00
# Epoch 15/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2603 - Accuracy: 0.0750 - val_loss: 139.1147 - val_Accuracy: 0.0000e+00
# Epoch 16/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2951 - Accuracy: 0.0500 - val_loss: 116.9186 - val_Accuracy: 0.0000e+00
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2224 - Accuracy: 0.0250 - val_loss: 128.6670 - val_Accuracy: 0.0000e+00
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3074 - Accuracy: 0.1000 - val_loss: 110.4096 - val_Accuracy: 0.0000e+00
# Epoch 19/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2970 - Accuracy: 0.0000e+00 - val_loss: 84.0239 - val_Accuracy: 0.0000e+00
# Epoch 20/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2811 - Accuracy: 0.0250 - val_loss: 88.0927 - val_Accuracy: 0.0000e+00
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2886 - Accuracy: 0.0000e+00 - val_loss: 85.9116 - val_Accuracy: 0.0000e+00
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2955 - Accuracy: 0.0500 - val_loss: 68.4290 - val_Accuracy: 0.0000e+00
# Epoch 23/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2426 - Accuracy: 0.0500 - val_loss: 23.0094 - val_Accuracy: 0.0000e+00
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2265 - Accuracy: 0.0250 - val_loss: 18.7178 - val_Accuracy: 0.1000
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2307 - Accuracy: 0.0250 - val_loss: 14.8305 - val_Accuracy: 0.1000
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2032 - Accuracy: 0.0750 - val_loss: 9.6377 - val_Accuracy: 0.1000
# Epoch 27/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2342 - Accuracy: 0.0500 - val_loss: 8.1356 - val_Accuracy: 0.1000
# Epoch 28/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2220 - Accuracy: 0.0250 - val_loss: 7.1802 - val_Accuracy: 0.1000
# Epoch 29/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2229 - Accuracy: 0.0250 - val_loss: 11.0095 - val_Accuracy: 0.0000e+00
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2265 - Accuracy: 0.0250 - val_loss: 10.3306 - val_Accuracy: 0.0000e+00
# Epoch 31/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1900 - Accuracy: 0.0250 - val_loss: 5.6387 - val_Accuracy: 0.0000e+00
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2122 - Accuracy: 0.0250 - val_loss: 4.7325 - val_Accuracy: 0.0000e+00
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2053 - Accuracy: 0.0500 - val_loss: 6.2351 - val_Accuracy: 0.0000e+00
# Epoch 34/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2127 - Accuracy: 0.0500 - val_loss: 4.5378 - val_Accuracy: 0.0000e+00
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1704 - Accuracy: 0.0250 - val_loss: 7.5198 - val_Accuracy: 0.1000
# Epoch 36/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2037 - Accuracy: 0.0500 - val_loss: 19.1761 - val_Accuracy: 0.0000e+00
# Epoch 37/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1942 - Accuracy: 0.0000e+00 - val_loss: 10.0507 - val_Accuracy: 0.1000
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2129 - Accuracy: 0.0250 - val_loss: 20.8466 - val_Accuracy: 0.0000e+00
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1547 - Accuracy: 0.1250 - val_loss: 16.1861 - val_Accuracy: 0.0000e+00
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1763 - Accuracy: 0.0250 - val_loss: 17.2705 - val_Accuracy: 0.0000e+00
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2245 - Accuracy: 0.0000e+00 - val_loss: 14.7207 - val_Accuracy: 0.0000e+00
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2016 - Accuracy: 0.0250 - val_loss: 16.9693 - val_Accuracy: 0.0000e+00
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2315 - Accuracy: 0.0250 - val_loss: 15.7774 - val_Accuracy: 0.0000e+00
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1774 - Accuracy: 0.0500 - val_loss: 19.1787 - val_Accuracy: 0.0000e+00
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1813 - Accuracy: 0.0500 - val_loss: 21.1137 - val_Accuracy: 0.0000e+00
# Epoch 46/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1708 - Accuracy: 0.0250 - val_loss: 14.8526 - val_Accuracy: 0.0000e+00
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1821 - Accuracy: 0.0750 - val_loss: 13.5541 - val_Accuracy: 0.0000e+00
# Epoch 48/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1318 - Accuracy: 0.0750 - val_loss: 8.0583 - val_Accuracy: 0.0000e+00
# Epoch 49/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1661 - Accuracy: 0.0750 - val_loss: 7.6828 - val_Accuracy: 0.0000e+00
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1893 - Accuracy: 0.0000e+00 - val_loss: 6.8773 - val_Accuracy: 0.0000e+00
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2266 - Accuracy: 0.0500 - val_loss: 6.2604 - val_Accuracy: 0.0000e+00
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1505 - Accuracy: 0.0500 - val_loss: 5.3567 - val_Accuracy: 0.0000e+00
# Epoch 53/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1633 - Accuracy: 0.0500 - val_loss: 5.3087 - val_Accuracy: 0.0000e+00
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1530 - Accuracy: 0.0500 - val_loss: 4.2970 - val_Accuracy: 0.0000e+00
# Epoch 55/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1457 - Accuracy: 0.0750 - val_loss: 3.2088 - val_Accuracy: 0.0000e+00
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1512 - Accuracy: 0.0750 - val_loss: 3.2157 - val_Accuracy: 0.0000e+00
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2132 - Accuracy: 0.0000e+00 - val_loss: 3.3396 - val_Accuracy: 0.0000e+00
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1912 - Accuracy: 0.0500 - val_loss: 2.6003 - val_Accuracy: 0.0000e+00
# Epoch 59/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1637 - Accuracy: 0.0750 - val_loss: 2.4645 - val_Accuracy: 0.0000e+00
# Epoch 60/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1575 - Accuracy: 0.0500 - val_loss: 2.4162 - val_Accuracy: 0.0000e+00
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1617 - Accuracy: 0.0500 - val_loss: 2.2351 - val_Accuracy: 0.0000e+00
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1340 - Accuracy: 0.0250 - val_loss: 1.9441 - val_Accuracy: 0.1000
# Epoch 63/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1732 - Accuracy: 0.0500 - val_loss: 1.7432 - val_Accuracy: 0.0000e+00
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1725 - Accuracy: 0.0250 - val_loss: 1.6603 - val_Accuracy: 0.0000e+00
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1145 - Accuracy: 0.0750 - val_loss: 1.6955 - val_Accuracy: 0.0000e+00
# Epoch 66/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0977 - Accuracy: 0.0750 - val_loss: 1.6579 - val_Accuracy: 0.0000e+00
# Epoch 67/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1471 - Accuracy: 0.0250 - val_loss: 1.6676 - val_Accuracy: 0.0000e+00
# Epoch 68/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0982 - Accuracy: 0.1000 - val_loss: 1.6048 - val_Accuracy: 0.0000e+00
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1342 - Accuracy: 0.0750 - val_loss: 1.7211 - val_Accuracy: 0.1000
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1546 - Accuracy: 0.0500 - val_loss: 1.9466 - val_Accuracy: 0.0000e+00
# Epoch 71/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1267 - Accuracy: 0.0500 - val_loss: 1.9724 - val_Accuracy: 0.0000e+00
# Epoch 72/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1202 - Accuracy: 0.1000 - val_loss: 1.9363 - val_Accuracy: 0.0000e+00
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1288 - Accuracy: 0.0500 - val_loss: 2.0246 - val_Accuracy: 0.1000
# Epoch 74/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1220 - Accuracy: 0.0500 - val_loss: 2.2299 - val_Accuracy: 0.1000
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1488 - Accuracy: 0.0750 - val_loss: 2.2624 - val_Accuracy: 0.0000e+00
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1061 - Accuracy: 0.0500 - val_loss: 2.1779 - val_Accuracy: 0.0000e+00
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1268 - Accuracy: 0.1000 - val_loss: 2.2639 - val_Accuracy: 0.0000e+00
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1273 - Accuracy: 0.0500 - val_loss: 2.2481 - val_Accuracy: 0.0000e+00
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1133 - Accuracy: 0.0250 - val_loss: 2.2303 - val_Accuracy: 0.0000e+00
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1192 - Accuracy: 0.0750 - val_loss: 2.3150 - val_Accuracy: 0.0000e+00
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0873 - Accuracy: 0.1000 - val_loss: 2.3934 - val_Accuracy: 0.0000e+00
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1235 - Accuracy: 0.0000e+00 - val_loss: 2.3833 - val_Accuracy: 0.0000e+00
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1017 - Accuracy: 0.0500 - val_loss: 2.4147 - val_Accuracy: 0.0000e+00
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0801 - Accuracy: 0.0750 - val_loss: 2.4856 - val_Accuracy: 0.0000e+00
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1157 - Accuracy: 0.0250 - val_loss: 2.5753 - val_Accuracy: 0.0000e+00
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1716 - Accuracy: 0.0000e+00 - val_loss: 2.6869 - val_Accuracy: 0.0000e+00
# Epoch 87/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1468 - Accuracy: 0.0250 - val_loss: 2.8401 - val_Accuracy: 0.0000e+00
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1028 - Accuracy: 0.0250 - val_loss: 2.8112 - val_Accuracy: 0.0000e+00
# Epoch 89/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0873 - Accuracy: 0.0750 - val_loss: 2.8871 - val_Accuracy: 0.0000e+00
# Epoch 90/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1011 - Accuracy: 0.0250 - val_loss: 2.9046 - val_Accuracy: 0.0000e+00
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0683 - Accuracy: 0.0500 - val_loss: 2.7801 - val_Accuracy: 0.0000e+00
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0807 - Accuracy: 0.1250 - val_loss: 2.9533 - val_Accuracy: 0.0000e+00
# Epoch 93/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0923 - Accuracy: 0.0750 - val_loss: 3.0047 - val_Accuracy: 0.0000e+00
# Epoch 94/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1202 - Accuracy: 0.0500 - val_loss: 3.0439 - val_Accuracy: 0.0000e+00
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1167 - Accuracy: 0.0750 - val_loss: 2.9998 - val_Accuracy: 0.0000e+00
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1178 - Accuracy: 0.0000e+00 - val_loss: 3.1373 - val_Accuracy: 0.0000e+00
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0708 - Accuracy: 0.0750 - val_loss: 3.1694 - val_Accuracy: 0.0000e+00
# Epoch 98/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0845 - Accuracy: 0.0500 - val_loss: 3.1642 - val_Accuracy: 0.0000e+00
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0635 - Accuracy: 0.0750 - val_loss: 3.1216 - val_Accuracy: 0.0000e+00
# Epoch 100/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0748 - Accuracy: 0.0500 - val_loss: 2.9912 - val_Accuracy: 0.0000e+00

# %% [markdown]
# ### Prediction Step

# %%
pred_test_op = model.predict(X_test, batch_size = 128)       # Perform Prediction on Test data
pred_train_op = model.predict(X_train, batch_size = 128)     # Perform Prediction on Training data

# %% [markdown]
# ### Model Validation

# %%
model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 1/1 [==============================] - 0s 20ms/step - loss: 2.9912 - Accuracy: 0.0000e+00
# [2.9911863803863525, 0.0]

# %% [markdown]
# ### Compare and Plot Actual and Predicted Test Coefficients

# %%
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(pred_test_op[0])        # Predicted Test Coefficient
ax.plot(y_test[0])              # Actual Test Coefficient

# %% [markdown]
# ### Inverse Transform of Predicted Spatial Coefficients

# %%
pred_alpha_k = np.zeros([alpha_k.shape[0], alpha_k.shape[1]])
pred_alpha_k[:,indices_test] = pred_test_op.T
pred_alpha_k[:,indices_train] = pred_train_op.T
pred_op = coff_scaler.inverse_transform(pred_alpha_k)    # Perform Inverse Tranform

# %% [markdown]
# ### Compare and Plot Actual and Predicted Test Coefficients

# %%
indices_test[0]
# Out:
# 28

# %%
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(pred_op.T[indices_test[0]])
ax.plot(alpha_k_.T[indices_test[0]])

# %% [markdown]
# ### Test Data Prediction - dot product of predicted spatial coefficients and orthogonal basis (PCA components)

# %%
y_ini_prediction.shape
# Out:
# (50, 61728)

# %%
test_pred = np.dot(pred_op.T, pca.components_[:K_])    # Predicted Test Data (dot product of predicted spatial coefficients and orthogonal basis - PCA components)
#y_pred = np.dot(coff_scaler.inverse_transform(alpha_k), pca.components_[:K_])
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(DateTime[:-1], test_pred[indices_test[0]], label = 'Predicted Test Data')          # Plot Predicted Test Data
ax.plot(DateTime[:-1], y_ini_prediction[indices_test[0]], label = 'Actual Transformed Data')   # Actual Transformed Data
ax.set_ylabel('pm2.5',fontsize=20)
ax.set_xlabel('Date Time',fontsize=20)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.legend(loc='best', fontsize=16)
plt.tight_layout()
#plt.savefig('fig/ignnk_pm2p5.pdf')
plt.show()

# %% [markdown]
# ### Plot Transformed predicted Test data and True Data

# %%
test_pred_trans = data_scaler.inverse_transform(test_pred)
y_pred_trans = data_scaler.inverse_transform(y_ini_prediction)
fig,ax = plt.subplots(figsize = (16,8))
ax.plot(DateTime[:-1], test_pred_trans[indices_test[0]], label = 'Prediction', linewidth = 2)
#ax.plot(y_ini_pred_trans[indices_test[0]])
ax.plot(DateTime[:-1], actual_data[indices_test[0]], label = 'True', linewidth = 2)
ax.set_ylabel('pm2.5',fontsize=20)
ax.set_xlabel('Date Time',fontsize=20)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
#ax.set_xticks(range(0,1000,50))
#ax.set_xticklabels(['0:00\nMar 3rd','4:00','8:00','12:00','16:00','20:00','0:00\nMar 4th'])
ax.legend(loc='best', fontsize=16)
plt.tight_layout()
#plt.savefig('nature_pm2p5_kmin_Nadam_0p0001.pdf')
plt.show()

# %% [markdown]
# ### Overall Mean Absolute Error between actual and Interpolated Data

# %%
print('Overall Mean Absolute Error is:', mae(actual_data, test_pred_trans))
#np.abs(actual_data[indices_test[0]]-test_pred_trans[indices_test[0]]).sum()/1000
# Out:
# Overall Mean Absolute Error is: 19.59189209181738

# %% [markdown]
# ### Mean Absolute Error Between Actual and Interpolated Data for Individual Sensors

# %%
List = np.sort(indices_test)
MAEs = []
for i in range(10):
    print('MEA for sensor {} is {}'.format( List[i], mae(actual_data[List[i]], test_pred_trans[List[i]])))
    MAEs.append(mae(actual_data[List[i]], test_pred_trans[List[i]]))
# Out:
# MEA for sensor 2 is 18.374654532581065
# MEA for sensor 4 is 22.435159000197142
# MEA for sensor 10 is 15.653454854064979
# MEA for sensor 11 is 20.935264679255106
# MEA for sensor 22 is 53.99055323426688
# MEA for sensor 27 is 13.230874856593836
# MEA for sensor 28 is 14.505586308096383
# MEA for sensor 31 is 10.299832152756204
# MEA for sensor 38 is 24.643008295815772
# MEA for sensor 41 is 35.017261141558805
